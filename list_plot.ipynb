# %% [markdown]
# <a href="https://colab.research.google.com/github/Oxygen0-0/study-2023sum/blob/main/list_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
x=[1,2,3,4,5]

# %%
plt.plot(x)
